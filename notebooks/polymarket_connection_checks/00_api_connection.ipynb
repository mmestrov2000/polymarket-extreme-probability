# %% [markdown]
# # Polymarket Connection Checks
#
# This notebook is reserved for Milestone 1 connectivity and payload validation.
#
# Goals:
# - verify public REST connectivity
# - inspect payload shape and stable identifiers
# - test WebSocket subscription flow
# - record sample payloads for later schema design

# %% [markdown]
# ## Planned checks
#
# 1. Gamma API market metadata
# 2. CLOB public endpoints for price and order book data
# 3. Data API wallet, holder, trade-history, and open-interest endpoints
# 4. WebSocket connectivity and sample live messages
# 5. Notes on auth, pagination, rate limits, and missing fields

# %%
# TODO: add imports, environment loading, and helper functions.

# %%
# TODO: add Gamma API checks and persist representative payload samples.

# %%
# TODO: add CLOB API checks for market state, price history, and trades.

# %%
# TODO: add Data API checks for wallet and holder research endpoints.

# %%
# TODO: add WebSocket probe code and capture example messages.

# %% [markdown]
# ## Findings template
#
# - Reachable endpoints:
# - Required auth or headers:
# - Stable market or token identifiers:
# - Useful wallet-related fields:
# - Missing data or blockers:
